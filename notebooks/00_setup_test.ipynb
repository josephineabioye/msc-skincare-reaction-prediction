# %% [markdown]
# <a href="https://colab.research.google.com/github/josephineabioye/msc-skincare-reaction-prediction/blob/main/notebooks/00_setup_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata

# Get token from Colab Secrets
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')

GITHUB_USERNAME = 'josephineabioye'
REPO_NAME = 'msc-skincare-reaction-prediction'
GIT_EMAIL = 'josephineabioye@yahoo.com'
GIT_NAME = 'Josephine Abioye'

# Clone the repo into Colab
# !git clone https://{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git

# Move into the cloned directory
# %cd {REPO_NAME}

# Set up git identity for this session
# !git config user.email "{GIT_EMAIL}"
# !git config user.name "{GIT_NAME}"

print(f"Cloned {REPO_NAME} successfully. You're now working inside the repo.")
# Out:
# Cloning into 'msc-skincare-reaction-prediction'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 98 (delta 48), reused 3 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 179.71 KiB | 2.90 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# /content/msc-skincare-reaction-prediction
# Cloned msc-skincare-reaction-prediction successfully. You're now working inside the repo.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# data  LICENSE  notebooks  README.md  references  results  src

# %%
# !ls /content/drive/MyDrive/msc-skincare-project/
# Out:
# data

# %%
# Create a test file in the notebooks folder
with open('notebooks/setup_test.md', 'w') as f:
    f.write("# Setup Test\n\nThis confirms Colab to GitHub connection is working.\n")

# Verify it exists
# !ls -a notebooks/
# Out:
# .  ..  .gitkeep  setup_test.md

# %%
# Stage the new file
# !git add notebooks/setup_test.md

# Commit with a message
# !git commit -m "Test: confirm Colab-GitHub connection"

# Push to GitHub
# !git push
# Out:
# [main 9005450] Test: confirm Colab-GitHub connection
#  1 file changed, 3 insertions(+)
#  create mode 100644 notebooks/setup_test.md
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 434 bytes | 434.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/josephineabioye/msc-skincare-reaction-prediction.git
#    7aa0042..9005450  main -> main
